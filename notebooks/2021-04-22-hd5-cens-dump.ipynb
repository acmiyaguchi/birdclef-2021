# %%
import pandas as pd

df = pd.read_hdf("../data/cens/train_short_audio/acafly/data.hd5")
df
# Out:
#          name  parent                                               data  \
# 0    XC109605  acafly  [-3.4471168e-07, 3.6376243e-06, -1.5128242e-06...
# 1     XC11209  acafly  [-5.5594504e-05, -0.0015144823, 0.004068937, -...
# 2    XC127032  acafly  [-1.2210558e-05, -1.8426263e-05, -1.7636668e-0...
# 3    XC129974  acafly  [3.314617e-08, -5.039625e-08, 9.996619e-08, -7...
# 4    XC129981  acafly  [2.7390568e-09, -1.4222666e-08, 5.1832593e-08,...
# ..        ...     ...                                                ...
# 127  XC580740  acafly  [-0.00013234008, 0.0002838285, -0.0014055393, ...
# 128  XC583856  acafly  [-1.5661219e-06, -2.7694816e-06, -2.8804427e-0...
# 129  XC594106  acafly  [5.5103473e-09, -5.6929763e-09, 2.879786e-09, ...
# 130  XC600277  acafly  [1.1152438e-06, -1.3263835e-06, 1.9514403e-06,...
# 131    XC6671  acafly  [2.213166e-06, 0.00018588777, 3.5043275e-05, -...
#
#      sample_rate                                               cens  \
# ...

# %%
df.cens[0].shape
# Out:
# (12, 646)
